# %%
is_genuine diagonal height_left height_right margin_low margin_up length

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Data_set/fake_bills.csv')

# %%
df
# Out:
#        True;171.81;104.86;104.95;4.52;2.89;112.83
# 0      True;171.46;103.36;103.66;3.77;2.99;113.09
# 1        True;172.69;104.48;103.5;4.4;2.94;113.16
# 2      True;171.36;103.91;103.94;3.62;3.01;113.51
# 3      True;171.73;104.28;103.46;4.04;3.48;112.54
# 4      True;172.17;103.74;104.08;4.42;2.95;112.81
# ...                                           ...
# 1494  False;171.75;104.38;104.17;4.42;3.09;111.28
# 1495  False;172.19;104.63;104.44;5.27;3.37;110.97
# 1496   False;171.8;104.01;104.12;5.51;3.36;111.95
# 1497  False;172.06;104.28;104.06;5.17;3.46;112.25
# 1498  False;171.47;104.15;103.82;4.63;3.37;112.07
#
# [1499 rows x 1 columns]

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('/content/drive/MyDrive/Data_set/fake_bills.csv', sep=';')

# Replace semicolon with comma
df.replace(';', ',', regex=True, inplace=True)

df.to_csv('output.csv', index=False)

# %%
df
# Out:
#        True  171.81  104.86  104.95  4.52  2.89  112.83
# 0      True  171.46  103.36  103.66  3.77  2.99  113.09
# 1      True  172.69  104.48  103.50  4.40  2.94  113.16
# 2      True  171.36  103.91  103.94  3.62  3.01  113.51
# 3      True  171.73  104.28  103.46  4.04  3.48  112.54
# 4      True  172.17  103.74  104.08  4.42  2.95  112.81
# ...     ...     ...     ...     ...   ...   ...     ...
# 1494  False  171.75  104.38  104.17  4.42  3.09  111.28
# 1495  False  172.19  104.63  104.44  5.27  3.37  110.97
# 1496  False  171.80  104.01  104.12  5.51  3.36  111.95
# 1497  False  172.06  104.28  104.06  5.17  3.46  112.25
# 1498  False  171.47  104.15  103.82  4.63  3.37  112.07
#
# [1499 rows x 7 columns]

# %%
# Rename the columns as per your specifications
df.columns = ['is_genuine', 'diagonal', 'height_left', 'height_right', 'margin_low', 'margin_up', 'length']

# Print the DataFrame with the updated column names
print(df)
# Out:
#       is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0           True    171.46       103.36        103.66        3.77       2.99
# 1           True    172.69       104.48        103.50        4.40       2.94
# 2           True    171.36       103.91        103.94        3.62       3.01
# 3           True    171.73       104.28        103.46        4.04       3.48
# 4           True    172.17       103.74        104.08        4.42       2.95
# ...          ...       ...          ...           ...         ...        ...
# 1494       False    171.75       104.38        104.17        4.42       3.09
# 1495       False    172.19       104.63        104.44        5.27       3.37
# 1496       False    171.80       104.01        104.12        5.51       3.36
# 1497       False    172.06       104.28        104.06        5.17       3.46
# 1498       False    171.47       104.15        103.82        4.63       3.37
#
#       length
# 0     113.09
# 1     113.16
# ...

# %%
df.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.46       103.36        103.66        3.77       2.99
# 1        True    172.69       104.48        103.50        4.40       2.94
# 2        True    171.36       103.91        103.94        3.62       3.01
# 3        True    171.73       104.28        103.46        4.04       3.48
# 4        True    172.17       103.74        104.08        4.42       2.95
#
#    length
# 0  113.09
# 1  113.16
# 2  113.51
# 3  112.54
# 4  112.81

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1499 entries, 0 to 1498
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   is_genuine    1499 non-null   bool
#  1   diagonal      1499 non-null   float64
#  2   height_left   1499 non-null   float64
#  3   height_right  1499 non-null   float64
#  4   margin_low    1462 non-null   float64
#  5   margin_up     1499 non-null   float64
#  6   length        1499 non-null   float64
# dtypes: bool(1), float64(6)
# memory usage: 71.9 KB

# %%
df.describe()
# Out:
#           diagonal  height_left  height_right   margin_low    margin_up  \
# count  1499.000000  1499.000000   1499.000000  1462.000000  1499.000000
# mean    171.958539   104.028979    103.919620     4.485944     3.151648
# std       0.305273     0.298792      0.324647     0.664039     0.231792
# min     171.040000   103.140000    102.820000     2.980000     2.270000
# 25%     171.750000   103.820000    103.710000     4.012500     2.990000
# 50%     171.960000   104.040000    103.920000     4.310000     3.140000
# 75%     172.170000   104.230000    104.150000     4.870000     3.310000
# max     173.010000   104.880000    104.950000     6.900000     3.910000
#
#             length
# count  1499.000000
# mean    112.678399
# std       0.873012
# min     109.490000
# 25%     112.030000
# 50%     112.960000
# 75%     113.340000
# max     114.440000

# %%
# prompt: plot using sns

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.pairplot(df)
plt.show()
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
df.isnull().sum()
# Out:
# is_genuine       0
# diagonal         0
# height_left      0
# height_right     0
# margin_low      37
# margin_up        0
# length           0
# dtype: int64

# %%
df.dropna(subset=['margin_low'], inplace=True)

# %%
df.isnull().sum()
# Out:
# is_genuine      0
# diagonal        0
# height_left     0
# height_right    0
# margin_low      0
# margin_up       0
# length          0
# dtype: int64

# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score

# Assuming 'is_genuine' is the target variable, and other features are predictors
X = df.drop('is_genuine', axis=1)
y = df['is_genuine']

# Handle missing values using SimpleImputer
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

# Number of neighbors for KNN
k_neighbors = 7

# Number of folds for cross-validation
num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# Initialize KNN classifier
knn_classifier = KNeighborsClassifier(n_neighbors=k_neighbors)

# Perform k-fold cross-validation
for train_index, test_index in kf.split(X_imputed):
    X_train, X_test = X_imputed[train_index], X_imputed[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the KNN model
    knn_classifier.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = knn_classifier.predict(X_test)

    # Evaluate the accuracy
    accuracy = accuracy_score(y_test, y_pred)
    print(f'Accuracy for fold: {accuracy}')
# Out:
# Accuracy for fold: 0.9897610921501706
# Accuracy for fold: 0.9931740614334471
# Accuracy for fold: 0.9863013698630136
# Accuracy for fold: 0.9897260273972602
# Accuracy for fold: 0.9897260273972602

# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score

# Assuming 'is_genuine' is the target variable, and other features are predictors
X = df.drop('is_genuine', axis=1)
y = df['is_genuine']

# Handle missing values using SimpleImputer
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

# Number of folds for cross-validation
num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# Range of odd values for the number of neighbors
k_neighbors_range = range(3, 61, 2)

# List to store average accuracies for each value of k_neighbors
avg_accuracies = []

for k_neighbors in k_neighbors_range:
    print(f"Number of Neighbors: {k_neighbors}")

    # Initialize KNN classifier
    knn_classifier = KNeighborsClassifier(n_neighbors=k_neighbors)

    # List to store accuracies for each fold
    fold_accuracies = []

    # Perform k-fold cross-validation
    for train_index, test_index in kf.split(X_imputed):
        X_train, X_test = X_imputed[train_index], X_imputed[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Train the KNN model
        knn_classifier.fit(X_train, y_train)

        # Make predictions on the test set
        y_pred = knn_classifier.predict(X_test)

        # Evaluate the accuracy
        accuracy = accuracy_score(y_test, y_pred)
        fold_accuracies.append(accuracy)
        print(f'Accuracy for fold: {accuracy}')

    # Calculate and print the average accuracy for the current k_neighbors
    avg_accuracy = sum(fold_accuracies) / len(fold_accuracies)
    avg_accuracies.append(avg_accuracy)
    print(f'Average Accuracy for k_neighbors={k_neighbors}: {avg_accuracy}')
    print('-' * 50)  # Separating different values of k_neighbors
# Out:
# Number of Neighbors: 3
# Accuracy for fold: 0.9863481228668942
# Accuracy for fold: 0.9931740614334471
# Accuracy for fold: 0.9863013698630136
# Accuracy for fold: 0.9897260273972602
# Accuracy for fold: 0.9931506849315068
# Average Accuracy for k_neighbors=3: 0.9897400532984244
# --------------------------------------------------
# Number of Neighbors: 5
# Accuracy for fold: 0.9931740614334471
# Accuracy for fold: 0.9931740614334471
# Accuracy for fold: 0.9863013698630136
# Accuracy for fold: 0.9931506849315068
# Accuracy for fold: 0.9931506849315068
# Average Accuracy for k_neighbors=5: 0.9917901725185845
# --------------------------------------------------
# Number of Neighbors: 7
# Accuracy for fold: 0.9897610921501706
# Accuracy for fold: 0.9931740614334471
# Accuracy for fold: 0.9863013698630136
# Accuracy for fold: 0.9897260273972602
# Accuracy for fold: 0.9897260273972602
# Average Accuracy for k_neighbors=7: 0.9897377156482303
# ...

# %%
# Plotting
plt.figure(figsize=(8, 6))
plt.plot( avg_accuracies, marker='o', linestyle='-', color='b')
plt.title('Average Accuracies for Experiments')
plt.xlabel('Experiments')
plt.ylabel('Average Accuracy')
plt.grid(True)
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score

# Assuming 'is_genuine' is the target variable, and other features are predictors
X = df.drop('is_genuine', axis=1)
y = df['is_genuine']

# Handle missing values using SimpleImputer
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

# Number of folds for cross-validation
num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# List to store average accuracies for each fold
avg_accuracies = []

# Range of regularization parameters (C values) for logistic regression
C_values = [0.001, 0.01, 0.1, 1, 10, ]

for C_value in C_values:
    # print(f"Regularization Parameter (C): {C_value}")

    # Initialize logistic regression classifier
    logistic_reg_classifier = LogisticRegression(C=C_value, random_state=42)

    # List to store accuracies for each fold
    fold_accuracies = []

    # Perform k-fold cross-validation
    for train_index, test_index in kf.split(X_imputed):
        X_train, X_test = X_imputed[train_index], X_imputed[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Train the logistic regression model
        logistic_reg_classifier.fit(X_train, y_train)

        # Make predictions on the test set
        y_pred = logistic_reg_classifier.predict(X_test)

        # Evaluate the accuracy
        accuracy = accuracy_score(y_test, y_pred)
        fold_accuracies.append(accuracy)
        # print(f'Accuracy for fold: {accuracy}')

    # Calculate and print the average accuracy for the current C_value
    avg_accuracy = sum(fold_accuracies) / len(fold_accuracies)
    avg_accuracies.append(avg_accuracy)
    # print(f'Average Accuracy for C={C_value}: {avg_accuracy}')
    # print('-' * 50)  # Separating different values of C_value

# %%
# Plotting
plt.figure(figsize=(8, 6))
plt.plot( avg_accuracies, marker='o', linestyle='-', color='b')
plt.title('Average Accuracies for Experiments')
plt.xlabel('Experiments')
plt.ylabel('Average Accuracy')
plt.grid(True)
plt.show()
